# %% [markdown]
# <a href="https://colab.research.google.com/github/arwahh/github-practice/blob/main/Type_casting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 5
result = float(x)
print(result)
# Out:
# 5.0

# %%
num = 12.76
result = int(num)
print(result)
# Out:
# 12

# %%
s = "123"
result = int(s)
print(result)
# Out:
# 123

# %%
s = "12"
result = int(s)

# %%
s = "45.89"
result = float(s)
print(result)
# Out:
# 45.89
