# %% [markdown]
# <a href="https://colab.research.google.com/github/arwahh/github-practice/blob/main/Slicing_and_Indexing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text = "python"
print(text[0])
# Out:
# p

# %%
text = "python"
print(text[-1])
# Out:
# n

# %%
text = "python"
print(text[1:4])
# Out:
# yth

# %%
text = "python"
print(text[:3])
# Out:
# pyt

# %%
text = "python"
print(text[3:])
# Out:
# hon

# %%
text = "python"
print(text[-3:])
# Out:
# hon

# %%
text = "python"
print(text[::2])
# Out:
# pto

# %%
text = "python"
print(text[::-1])
# Out:
# nohtyp
