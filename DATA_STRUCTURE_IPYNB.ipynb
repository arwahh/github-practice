# %% [markdown]
# <a href="https://colab.research.google.com/github/arwahh/github-practice/blob/main/DATA_STRUCTURE_IPYNB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nums = [1, 2, 3, 4, 5, 6]
for n in nums:
    if n % 2 == 0:
        print(n)
# Out:
# 2
# 4
# 6

# %%
fruits = ["apple", "banana", "mango"]
fruits.append("orange")
fruits.remove("banana")
print(fruits)
# Out:
# ['apple', 'mango', 'orange']

# %%
t = (10, 20, 30, 40)
print(t.index(30))
# Out:
# 2

# %%
a = {1, 2, 3, 4}
b = {3, 4, 5}
print(a.intersection(b))
# Out:
# {3, 4}

# %%
nums = [1, 2, 2, 3, 4, 4, 5]
unique = list(set(nums))
print(unique)
# Out:
# [1, 2, 3, 4, 5]

# %%
student = {"name": "Ali", "age": 20, "city": "Delhi"}

for k, v in student.items():
    print(k, ":", v)
# Out:
# name : Ali
# age : 20
# city : Delhi

# %%
info = {"brand": "Toyota", "year": 2015}
info["color"] = "white"
print(info)
# Out:
# {'brand': 'Toyota', 'year': 2015, 'color': 'white'}

# %%
stack = []
stack.append(10)
stack.append(20)
stack.pop()     # removes 20
print(stack)
# Out:
# [10]
