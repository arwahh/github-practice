# %% [markdown]
# <a href="https://colab.research.google.com/github/arwahh/github-practice/blob/main/tuple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
colors = ("red", "blue", "green")
print(colors)
# Out:
# ('red', 'blue', 'green')

# %%
numbers = (10, 20, 30, 40)
print(numbers[0])
print(numbers[-1])
# Out:
# 10
# 40

# %%
fruits = ("apple", "banana", "mango")
if "apple" in fruits:
    print("Apple is present!")
# Out:
# Apple is present!

# %%
names = ("Arwah", "Sara", "falak")
print(len(names))
# Out:
# 3

# %%
my_tuple = ("hello", 25, [1, 2, 3], True)
print(my_tuple)
# Out:
# ('hello', 25, [1, 2, 3], True)

# %%
letters = ("a", "b", "a", "c", "a")
print(letters.count("a"))
# Out:
# 3

# %%
data = ("Arwa", 23, "Delhi")
name, age, city = data
print(name, age, city)
# Out:
# Arwa 23 Delhi

# %%
t = (10, 20, 30)
my_list = list(t)
print(my_list)
# Out:
# [10, 20, 30]
