# %% [markdown]
# <a href="https://colab.research.google.com/github/arwahh/github-practice/blob/main/SETS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_set = {1, 2, 3, 4}
print(my_set)
# Out:
# {1, 2, 3, 4}

# %%
s = {10, 20, 30}
s.add(40)
print(s)
# Out:
# {40, 10, 20, 30}

# %%
s = {1, 2}
s.update([3, 4, 5])
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
s = {10, 20, 30}
s.remove(20)
print(s)
# Out:
# {10, 30}

# %%
s = {10, 20, 30}
s.discard(50)
print(s)
# Out:
# {10, 20, 30}

# %%
s = {1, 2, 3, 4}
x = s.pop()
print(x)
print(s)
# Out:
# 1
# {2, 3, 4}

# %%
a = {1, 2, 3}
b = {3, 4, 5}
print(a.union(b))
# Out:
# {1, 2, 3, 4, 5}

# %%
a = {1, 2, 3}
b = {2, 3, 4}
print(a.intersection(b))
# Out:
# {2, 3}
